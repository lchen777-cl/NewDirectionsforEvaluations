# %%
import requests
import re
from bs4 import BeautifulSoup
import string
import pandas as pd
from pathlib import Path
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from pyshadow.main import Shadow
import pandas as pd
import csv, os
from selenium.common.exceptions import NoSuchElementException
import time

# %%
def Download_Citation(Volume, Issue):
    driver = webdriver.Chrome(ChromeDriverManager().install())
    #driver.execute_script("window.open('https://onlinelibrary.wiley.com/toc/1534875x/"+str(Volume)+"/"+str(Volume)+"/"+str(Issue)+"/');")
    driver.get("https://onlinelibrary.wiley.com/toc/1534875x/"+str(Volume)+"/"+str(Volume)+"/"+str(Issue))
    driver.find_element(By.CSS_SELECTOR, "a[class='bulk-download-option'] span").click()
    Research_Articles = driver.find_elements(By.CLASS_NAME,'checkbox--primary')
    for a in Research_Articles[1:]:
        a.click()
    driver.find_element(By.CSS_SELECTOR, ".bulk-wizard.exportCitationsForm").click()
    driver.find_element(By.CSS_SELECTOR, ".export-citations__submit").click()
    time.sleep(5)
    driver.quit()

# %%
def Ref(html_name): 
    Ref = []
    with open('/Users/langchen777/Desktop/NewDirectionsforEvaluations/New Directions for Evaluations/HTML/'+html_name+'.html', 'r', encoding = 'utf-8') as f:
        soup = BeautifulSoup(f.read())
        content = soup.findAll("li")
    for li in content:
        authors = li.findAll("span", class_="author")
        line = []
        for x in authors:
            line.append(x.contents[0])
        while(len(line)<5):
            line.append("")
        while(len(line)>5):
            line.pop()
        try:
            title = li.find("span", class_="articleTitle").text
        except AttributeError:
            pass
        try:
            title = li.find("span", class_="chapterTitle").text
        except AttributeError:
            pass
        try:
            title = li.find("span", class_="bookTitle").text
        except AttributeError:
            pass
        try:
            title = li.find("span", class_="otherTitle").text
        except AttributeError:
            pass
        line.append(title)
        Ref.append(line)
    return Ref

# %%
col=['AU1_r','AU2_r','AU3_r','AU4_r','AU5_r','TI_r','TY']
for i in range(1,11):
    col.append('AU'+str(i))
col = col + ["TI","JO","VL","IS","SN","DO","SP","EP"]
        #a_series = pd.Series(line, index = df.columns)
        #df = df.append(a_series, ignore_index=True)

# %%
def Issue(issue):
    df = pd.DataFrame(columns=col)
    file = open('/Users/langchen777/Downloads/pericles_exported_citations.txt', 'r')
    Lines = file.readlines()
    count = 0
    for line in Lines:
        start = line[:2]
        if start == "TY":
            count = count + 1
            #Ref = Ref()
            row = []
            row.append(line.split("-",1)[1].strip())
        elif start == "AU":
            row.append(line.split("-",1)[1].strip())
        elif start == "TI":
            while(len(row)<11):
                row.append("")
            while(len(row)>11):
                row.pop()
            row.append(line.split("-",1)[1].strip())
        elif start in ["JO","VL","IS","SN","DO","SP","EP"]:
            row.append(line.split("-",1)[1].strip())
        elif start == "ER":
            try:
                for r in Ref(str(issue)+str(count)):
                    combine = r + row
                    a_series = pd.Series(combine, index = col)
                    df = df.append(a_series, ignore_index=True)
            except FileNotFoundError:
                pass
            else:
                r = ["","","","","",""]
                combine = r + row
    os.remove("/Users/langchen777/Downloads/pericles_exported_citations.txt")
    return df

# %%
def Return_Issue(i):
    if i in range(1,5):
        volume = 1978
    else:
        volume = 1979 + (i-1)//4
    Download_Citation(volume, i)
    df=Issue(i)
    return df

# %%
df = pd.DataFrame(columns=col)
for i in range (81,85):
    df = df.append(Return_Issue(i))
    print(df.tail())
df.to_csv('1999.csv')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [/Users/langchen777/.wdm/drivers/chromedriver/mac64/97.0.4692.71/chromedriver] found in cache
# <ipython-input-24-04f0a9228132>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
#            AU1_r            AU2_r AU3_r AU4_r AU5_r  \
# 73    Schrag, P.
# 74  Tabarrok, A.
# 75    Thomas, C.  Hrebenar, R. J.
# 76    Weberg, B.
# 77      Will, G.
#
#                                                  TI_r    TY            AU1  \
# 73  The Populist Road to Hell: Term Limits in Cali...  JOUR  Mohan, Rakesh
# 74  A Survey, Critique and New Defense of Term Limits  JOUR  Mohan, Rakesh
# 75                    Politics in the American States  JOUR  Mohan, Rakesh
# 76                New Age Dawns for Legislative Staff  JOUR  Mohan, Rakesh
# 77  Restoration: Congress, Term Limits, and the Re...  JOUR  Mohan, Rakesh
#
#                AU2 AU3  ... AU9 AU10  \
# 73  Stutzman, Mary      ...
# 74  Stutzman, Mary      ...
# 75  Stutzman, Mary      ...
# 76  Stutzman, Mary      ...
# 77  Stutzman, Mary      ...
#
#                                                    TI  \
# 73  The impact of term limits on legislative progr...
# 74  The impact of term limits on legislative progr...
# 75  The impact of term limits on legislative progr...
# 76  The impact of term limits on legislative progr...
# 77  The impact of term limits on legislative progr...
#
#                                JO    VL  IS         SN  \
# 73  New Directions for Evaluation  1999  81  1097-6736
# 74  New Directions for Evaluation  1999  81  1097-6736
# 75  New Directions for Evaluation  1999  81  1097-6736
# 76  New Directions for Evaluation  1999  81  1097-6736
# 77  New Directions for Evaluation  1999  81  1097-6736
#
#                                  DO  SP   EP
# 73  https://doi.org/10.1002/ev.1130  95  105
# 74  https://doi.org/10.1002/ev.1130  95  105
# 75  https://doi.org/10.1002/ev.1130  95  105
# 76  https://doi.org/10.1002/ev.1130  95  105
# 77  https://doi.org/10.1002/ev.1130  95  105
#
# [5 rows x 25 columns]
# Driver [/Users/langchen777/.wdm/drivers/chromedriver/mac64/97.0.4692.71/chromedriver] found in cache
# <ipython-input-24-04f0a9228132>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
#               AU1_r       AU2_r          AU3_r           AU4_r  \
# 172
# 173        Gill, C.
# 174   Hendricks, M.  Connor, R.  W. R. Shadish       D. Newman
# 175     Mertens, D.  W. Shadish      D. Newman  M. A. Scheirer
# 176  Pollard, D. S.
#
#               AU5_r                                               TI_r    TY  \
# 172                  CDC Overseas Research Doesn't Include Ethics A...  JOUR
# 173                  Invisible Ubiquity: The Surprising Relevance o...  JOUR
# 174  M. A. Scheirer  International Perspectives on the Guiding Prin...  JOUR
# 175          C. Wye  Identifying and Respecting Differences Among P...  JOUR
# 176                        Towards a Pluralistic Perspective on Equity  JOUR
#
#                     AU1 AU2 AU3  ... AU9 AU10  \
# 172  Bamberger, Michael          ...
# 173  Bamberger, Michael          ...
# 174  Bamberger, Michael          ...
# 175  Bamberger, Michael          ...
# 176  Bamberger, Michael          ...
#
#                                                     TI  \
# 172  Ethical issues in conducting evaluation in int...
# 173  Ethical issues in conducting evaluation in int...
# 174  Ethical issues in conducting evaluation in int...
# 175  Ethical issues in conducting evaluation in int...
# 176  Ethical issues in conducting evaluation in int...
#
#                                 JO    VL  IS         SN  \
# 172  New Directions for Evaluation  1999  82  1097-6736
# 173  New Directions for Evaluation  1999  82  1097-6736
# 174  New Directions for Evaluation  1999  82  1097-6736
# 175  New Directions for Evaluation  1999  82  1097-6736
# 176  New Directions for Evaluation  1999  82  1097-6736
#
#                                   DO  SP  EP
# 172  https://doi.org/10.1002/ev.1140  89  97
# 173  https://doi.org/10.1002/ev.1140  89  97
# 174  https://doi.org/10.1002/ev.1140  89  97
# 175  https://doi.org/10.1002/ev.1140  89  97
# 176  https://doi.org/10.1002/ev.1140  89  97
#
# [5 rows x 25 columns]
# Driver [/Users/langchen777/.wdm/drivers/chromedriver/mac64/97.0.4692.71/chromedriver] found in cache
# <ipython-input-24-04f0a9228132>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
#               AU1_r          AU2_r AU3_r AU4_r AU5_r  \
# 134  Wandersman, A.
# 135    Weiss, C. H.
# 136    Weiss, C. H.
# 137   Wholey, J. S.
# 138      Winick, C.  Larson, M. J.
#
#                                                   TI_r    TY            AU1  \
# 134  Comprehensive Quality Programming: Eight Essen...  JOUR  Saxe, Leonard
# 135      Using Social Research in Public Policy Making  JOUR  Saxe, Leonard
# 136     Knowledge and Policy: The Uncertain Connection  JOUR  Saxe, Leonard
# 137         Evaluation and Effective Public Management  JOUR  Saxe, Leonard
# 138          Substance Abuse: A Comprehensive Textbook  JOUR  Saxe, Leonard
#
#                   AU2 AU3  ... AU9 AU10  \
# 134  Tighe, Elizabeth      ...
# 135  Tighe, Elizabeth      ...
# 136  Tighe, Elizabeth      ...
# 137  Tighe, Elizabeth      ...
# 138  Tighe, Elizabeth      ...
#
#                                                     TI  \
# 134  The view from Main Street and the view from 40...
# 135  The view from Main Street and the view from 40...
# 136  The view from Main Street and the view from 40...
# 137  The view from Main Street and the view from 40...
# 138  The view from Main Street and the view from 40...
#
#                                 JO    VL  IS         SN  \
# 134  New Directions for Evaluation  1999  83  1097-6736
# 135  New Directions for Evaluation  1999  83  1097-6736
# 136  New Directions for Evaluation  1999  83  1097-6736
# 137  New Directions for Evaluation  1999  83  1097-6736
# 138  New Directions for Evaluation  1999  83  1097-6736
#
#                                   DO  SP  EP
# 134  https://doi.org/10.1002/ev.1146  67  86
# 135  https://doi.org/10.1002/ev.1146  67  86
# 136  https://doi.org/10.1002/ev.1146  67  86
# 137  https://doi.org/10.1002/ev.1146  67  86
# 138  https://doi.org/10.1002/ev.1146  67  86
#
# [5 rows x 25 columns]
# Driver [/Users/langchen777/.wdm/drivers/chromedriver/mac64/97.0.4692.71/chromedriver] found in cache
# <ipython-input-24-04f0a9228132>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
#                 AU1_r                AU2_r AU3_r AU4_r AU5_r  \
# 158    Sheehan, K. B.           Hoy, M. G.
# 159       Shum, S. B.
# 160       Stewart, J.         Williams, R.
# 161      Stone, D. L.  Stone-Romero, E. F.
# 162  Trochim, W. M. K
#
#                                                   TI_r    TY  \
# 158  Using E-Mail to Survey Internet Users in the U...  JOUR
# 159    Information Technology for Knowledge Management  JOUR
# 160  The Coevolution of Society and Mutimedia Techn...  JOUR
# 161  Managerial Ethics: Moral Management of People ...  JOUR
# 162  An Introduction to Concept Mapping for Plannin...  JOUR
#
#                       AU1 AU2 AU3  ... AU9 AU10  \
# 158  Bennington, Tammy L.          ...
# 159  Bennington, Tammy L.          ...
# 160  Bennington, Tammy L.          ...
# 161  Bennington, Tammy L.          ...
# 162  Bennington, Tammy L.          ...
#
#                                                     TI  \
# 158  Ethical implications of computer-mediated eval...
# 159  Ethical implications of computer-mediated eval...
# 160  Ethical implications of computer-mediated eval...
# 161  Ethical implications of computer-mediated eval...
# 162  Ethical implications of computer-mediated eval...
#
#                                 JO    VL  IS         SN  \
# 158  New Directions for Evaluation  1999  84  1097-6736
# 159  New Directions for Evaluation  1999  84  1097-6736
# 160  New Directions for Evaluation  1999  84  1097-6736
# 161  New Directions for Evaluation  1999  84  1097-6736
# 162  New Directions for Evaluation  1999  84  1097-6736
#
#                                   DO  SP   EP
# 158  https://doi.org/10.1002/ev.1155  87  103
# 159  https://doi.org/10.1002/ev.1155  87  103
# 160  https://doi.org/10.1002/ev.1155  87  103
# 161  https://doi.org/10.1002/ev.1155  87  103
# 162  https://doi.org/10.1002/ev.1155  87  103
#
# [5 rows x 25 columns]
