# %%
import urllib3

http = urllib3.PoolManager()
r = http.request('get', 'https://onlinelibrary.wiley.com/doi/full/10.1002/ev.20469',headers={'username':'remichen@g.ucle.edu','password':'Cloudnine(9)','authenticity_token':'6134da05-7ebf-41dd-89ba-b73b0c72e32c'})
reference = r.data.decode('utf-8')
reference
# Out:
# '<!DOCTYPE html>\n<html lang="en"     class="pb-page"  data-request-id="bafdb6e1-9928-43fa-ac42-67a6b5ca1ecf"  \n><head data-pb-dropzone="head"><meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="pbContext" content=";csubtype:string:Special;page:string:Article/Chapter View;ctype:string:Journal Content;website:website:pericles;subPage:string:Access Denial;issue:issue:doi\\:10.1002/ev.v2021.171;journal:journal:15512371;wgroup:string:Publication Websites;pageGroup:string:Publication Pages;article:article:doi\\:10.1002/ev.20469;requestedJournal:journal:1534875x"/>\n\n<script type="text/javascript">var $DoubleClickZone = "new-directs-evaluation_ev";var $DoubleClickSite =  "wly.education_000048";</script><script id="analyticDigitalData">digitalData = {"site":{"ip":"2603:8001:6600:a33e:4144:64ca:c4e9:7141","environment":"LIVE","website":"onlinelibrary.wiley.com","websiteCode":"pericles","serverDate":"2022-01-13"},"identities":[{"type":"SmartGroupUser","uuid":"b238ab85-6bb4-49e4-84ca-a0d9f3ee5a35"},{"type":"SmartGroupUser","uuid":"eabce89b-65c2-4a09-ab7c-bd2b3fea2f10"},{"type":"RegionUser","uuid":"3c5060a1-6620-438f-862b-902a4d4cd4ac"},{"type":"BasicGroup","uuid":"e623deab-c83b-41e3-84a2-d9f1d46c5f17"},{"type":"SmartGroupUser","uuid":"a86d27d2-6bcd-4b94-bca5-fe16f4882855"},{"type":"UserAgentUser","uuid":"9566188c-579a-4e7f-8100-ba09c4148156"},{"type":"UserAgentUser","uuid":"c989989e-9684-4abd-958e-175c88712a7a"},{"type":"SmartGroupUser","uuid":"da88d808-3f7b-4bde-9210-10862b6d121b"},{"type":"SmartGroupUser","uuid":"8c72a733-117a-4bc9-a682-13475f13e6a3"},{"type":"SmartGroupUser","uuid":"756fc162-8722-461f-a077-ebffec4f4fae"},{"type":"SmartGroupUser","uuid":"cf9c85b9-7f3b-4309-aeaa-c41669cabe3b"},{"type":"SmartGroupUser","uuid":"db8b8d10-1aed-4809-b3ee-70938c569014"},{"type":"SmartGroupUser","uuid":"cdce41c2-a8de-4a64-a4d9-a85caaaa2314"},{"type":"SmartGroupUser","uuid":"39f911ce-44b6-4dba-9978-8b2e947a8eb0"},{"type":"RegionUser","uuid":"18971d33-e3f1-4194-be84-47668d10cf64"},{"type":"SmartGroupUser","uuid":"b7acda8c-ce18-451b-a68d-e14b72f9b5b8"},{"type":"SmartGroupUser","uuid":"055a2bdd-861f-4fa7-bd49-9773db7e0e3e"},{"type":"BasicGroup","uuid":"197fe835-5b5f-4f4e-b8e9-a74d68491a84"},{"type":"SmartGroupUser","uuid":"b2dbfe27-ecae-4bb6-bb0d-d75e5caa3762"},{"type":"SmartGroupUser","uuid":"1a6297fb-6679-4882-a4c2-fdd124624edf"},{"type":"BasicGroup","uuid":"fd99905c-4b60-4cb9-b576-5529f7a031dd","customerRecords":[{"customerDomain":"ALM-CU","customerNumber":"TESTOHIOSTATECOCHRANE"}]},{"type":"SmartGroupUser","uuid":"8032f17e-5050-4fb4-9c40-e1f6875d5c2b"},{"type":"SmartGroupUser","uuid":"ab743440-628f-4964-9216-9983ad3beadf"},{"type":"SmartGroupUser","uuid":"a4187e00-f28e-4754-9a0f-1eb306fb0679"}],"publication":{"item":{"title":"As technology disrupts equity, advocates take action: Where do evaluators fit in?","doi":"10.1002/ev.20469","access":"no","earliestDate":"2021-09-24","formats":["Abstract","First page image","Full text","PDF","References","AM pdf"],"topics":[{"taxonomyUri":"global-subject-codes","topicLabel":"Educational Research \\u0026 Statistics","topicUri":"ed04"},{"taxonomyUri":"global-subject-codes","topicLabel":"CULTURAL STUDIES","topicUri":"cu"},{"taxonomyUri":"global-subject-codes","topicLabel":"Higher Education General","topicUri":"ed20"},{"taxonomyUri":"global-subject-codes","topicLabel":"Research Methodologies","topicUri":"so90"},{"taxonomyUri":"global-subject-codes","topicLabel":"General \\u0026 Introductory Education","topicUri":"ed00"},{"taxonomyUri":"global-subject-codes","topicLabel":"Survey Research Methods \\u0026 Sampling","topicUri":"st60"},{"taxonomyUri":"global-subject-codes","topicLabel":"Public Health General","topicUri":"he50"},{"taxonomyUri":"global-subject-codes","topicLabel":"PSYCHOLOGY","topicUri":"ps"},{"taxonomyUri":"global-subject-codes","topicLabel":"Applied Probability \\u0026 Statistics","topicUri":"st20"},{"taxonomyUri":"global-subject-codes","topicLabel":"Cultural Studies General","t ...

# %%
file = open("/Users/langchen777/Desktop/NewDirectionsforEvaluations/reference.html","w")
file.write(reference)
file.close()

# %%
from bs4 import BeautifulSoup
with open('/Users/langchen777/Desktop/NewDirectionsforEvaluations/reference.html', 'r', encoding = 'utf-8') as f:
    soup = BeautifulSoup(f.read())
    content = soup.findAll("li")
for li in content:
    authors = li.findAll("span", class_="author")
    line = []
    for x in authors:
        line.append(x.contents[0])
    while(len(line)<5):
        line.append("")
    while(len(line)>5):
        line.pop()
    try:
        title = li.find("span", class_="articleTitle").text
    except AttributeError:
        pass
    try:
        title = li.find("span", class_="chapterTitle").text
    except AttributeError:
        pass
    try:
        title = li.find("span", class_="bookTitle").text
    except AttributeError:
        pass
    try:
        title = li.find("span", class_="otherTitle").text
    except AttributeError:
        pass
    line.append(title)
    print(line)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-922cb7d7c407> in <module>
#      28     except AttributeError:
#      29         pass
# ---> 30     line.append(title)
#      31     print(line)
#
# NameError: name 'title' is not defined

# %%
import urllib3

http = urllib3.PoolManager()
myHeaders = urllib3.util.make_headers(basic_auth='remichen@g.ucla.edu:Cloudnine(9)')
r = http.request('GET', 'https://onlinelibrary.wiley.com/doi/full/10.1002/ev.20469', headers=myHeaders)
reference = r.data.decode('utf-8')
reference
# Out:
# 'Wiley Online Library requires cookies for authentication and use of other site features; therefore, cookies must be enabled to browse the site. Detailed information on how Wiley uses cookies can be found in our Privacy Policy [https://www.wiley.com/en-us/privacy].\n'

# %%
import certifi
import urllib3

http = urllib3.PoolManager(
    cert_reqs="CERT_REQUIRED",
    ca_certs=certifi.where()
)

r = http.request("GET", "https://onlinelibrary.wiley.com/doi/full/10.1002/ev.20469")
reference = r.data.decode('utf-8')
reference
# Out:
# 'Wiley Online Library requires cookies for authentication and use of other site features; therefore, cookies must be enabled to browse the site. Detailed information on how Wiley uses cookies can be found in our Privacy Policy [https://www.wiley.com/en-us/privacy].\n'

# %%
import requests
import re
from bs4 import BeautifulSoup
import string
import pandas as pd
from pathlib import Path
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from pyshadow.main import Shadow
import pandas as pd
import csv, os
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
#driver.execute_script("window.open('https://onlinelibrary.wiley.com/toc/1534875x/"+str(Volume)+"/"+str(Volume)+"/"+str(Issue)+"/');")
driver.get("https://onlinelibrary.wiley.com/doi/full/10.1002/ev.20469")
driver.find_element(By.CSS_SELECTOR, ".sign-in-label").click()
driver.find_element(By.CSS_SELECTOR, "#username").send_keys("remichen@g.ucla.edu")
driver.find_element(By.CSS_SELECTOR, "#password").send_keys("Cloudnine(9)")
driver.find_element(By.CSS_SELECTOR, "input[value='Log In']").click()
import urllib3

http = urllib3.PoolManager()
r = http.request('get', 'https://onlinelibrary.wiley.com/doi/full/10.1002/ev.20469',headers={"basic_auth":'remichen@g.ucla.edu:Cloudnine(9)',"token": "6134da05-7ebf-41dd-89ba-b73b0c72e32c"})
reference = r.data.decode('utf-8')
reference
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [/Users/langchen777/.wdm/drivers/chromedriver/mac64/97.0.4692.71/chromedriver] found in cache
# <ipython-input-7-a00d94d8f69a>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 'Wiley Online Library requires cookies for authentication and use of other site features; therefore, cookies must be enabled to browse the site. Detailed information on how Wiley uses cookies can be found in our Privacy Policy [https://www.wiley.com/en-us/privacy].\n'

# %%
import urllib.request, json

url = "https://onlinelibrary.wiley.com/doi/full/10.1002/ev.20469"
data = {
    "username" : "remichen@g.ucla.edu",
    "password" : "Cloudnine(9)"
}

jsonData = json.dumps(data).encode('utf-8')

req = urllib.request.Request(url, data=jsonData, headers={
    'content-type': 'application/json'
    })

response = urllib.request.urlopen(req)
cookies = response.getheader("Set-Cookie")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-14-edef211a19bc> in <module>
#      13     })
#      14
# ---> 15 response = urllib.request.urlopen(req)
#      16 cookies = response.getheader("Set-Cookie")
#
# ~/LangChen777/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/LangChen777/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/LangChen777/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/LangChen777/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/LangChen777/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/LangChen777/anaconda3/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden
